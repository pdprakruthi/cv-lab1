# %%
from PIL import Image

# Load the image with double backslashes
image = Image.open('C:\\Users\\Prakruthi P D\\OneDrive\\Desktop\\darshu.jpg').convert('L')  # Convert to grayscale

# Get pixel values
pixel_values = list(image.getdata())

# Find the minimum and maximum pixel values
min_pixel = min(pixel_values)
max_pixel = max(pixel_values)

print(f'Min pixel value: {min_pixel}')
print(f'Max pixel value: {max_pixel}')
# Out:
# Min pixel value: 0
# Max pixel value: 255

# %%
# Histogram of Blue component
b_count = np.unique(b, return_counts = True)
b_count = dict(np.asarray(b_count).T)
b_hist = [0]*256
for i in b_count.keys():
    b_hist[i] = b_count[i]
plt.plot(b_hist, '-b')
plt.title('Histogram of Blue Component')
plt.xlabel('Intensity Value')
plt.ylabel('Frequency')
plt.show()
